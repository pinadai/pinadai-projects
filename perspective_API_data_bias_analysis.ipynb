# %% [markdown]
# ### Perspective API Exploration
#
# First, we have a dataset of Wikipedia comments made available by Jigsaw, a subsidiary of Google that created the Perspective tool. The dataset includes a unique comment id, the text of the comment, and a series of binary labels applied by human raters: "toxic," "severe_toxic," "obscene," "threat," "insult," and "identity_hate." I have appended the "score" column, which represents the toxicity score assigned to the comment text by the live version of the Perspective API. The data is available under a CC0 license.

# %% [markdown]
# Reading in CSV file of comments

# %%
import pandas as pd
import time

df = pd.read_csv('labeled_and_scored_comments.csv')

# %% [markdown]
# Sorting the dataset of comments by score, from lowest to highest.

# %%
df.sort_values(['score'])
# Out:
#                      id                                       comment_text  \
# 1158   61a85266de70cca0                         Можешь говорить по русски.
# 5246   030a9ba0b32b4456  Rodzina Krusenstern Potomkowie Admirała Adama ...
# 11040  a6814193ac6b4705  The opening paragraph states that the game is ...
# 24192  f0d6dee96e057a5b  The book is used as a source in a number of ar...
# 2332   cbb9268d3c7429c1     Vals Vienés \n |Rumba \n |Cha Cha Chá(ciclo 7)
# ...                 ...                                                ...
# 19994  1429a2c930688317                          you fucking piece of shit
# 28728  d82e45eb103ad07b                   fuck off you stupid aspy asshole
# 25535  e9b92c6c6b01aeef  FUCK YOU YOU PIECE OF SHIT \n FUCK YOU YOU PIE...
# 25945  e783fd267f3a9d3b  FUCK WIKIPEDIA ON WHEELS! \n\nFuck off wikiped...
# 17833  364b6c24210e2345  Fuck you you fucking pig!\n\nYou motherfucking...
#
#           score  toxic  severe_toxic  obscene  threat  insult  identity_hate
# 1158   0.000004      0             0        0       0       0              0
# 5246   0.000009      0             0        0       0       0              0
# 11040  0.000091      0             0        0       0       0              0
# 24192  0.000116      0             0        0       0       0              0
# 2332   0.000131      0             0        0       0       0              0
# ...         ...    ...           ...      ...     ...     ...            ...
# 19994  0.997278      1             1        1       0       1              0
# 28728  0.997736      1             1        1       0       1              0
# 25535  0.997982      1             1        1       0       1              0
# 25945  0.998136      1             1        1       0       1              0
# 17833  0.998329      1             0        1       0       1              0
#
# [41338 rows x 9 columns]

# %% [markdown]
# I've also included a function to make calls to the Perspective API for your own testing. You will need to generate your own API key according to the instructions in the assignment.

# %%
from googleapiclient.discovery import build
import json

def get_toxicity_score(comment):
    
  API_KEY = 'XXXXXX' # Put your API key here
    
  client = build(
  "commentanalyzer",
  "v1alpha1",
  developerKey=API_KEY,
  discoveryServiceUrl="https://commentanalyzer.googleapis.com/$discovery/rest?version=v1alpha1"
  )

  analyze_request = {
  'comment': { 'text': comment },
  'requestedAttributes': {'TOXICITY': {}}
  }
    
  response = client.comments().analyze(body=analyze_request).execute()
  toxicity_score = response["attributeScores"]["TOXICITY"]["summaryScore"]["value"]
    
  return toxicity_score

# %% [markdown]
# Extracting all comments with the "toxic" label from the dataset. This label was chosen to evaluate the dataset because
# it's the broadest out of all the labels. This assignment will only be looking at how the model scores comments as toxic vs. how manual reviewers have scored comments as toxic.

# %%
toxic_comments = df[(df['toxic']==1)]

# %% [markdown]
# Determining a threshold for the model

# %%
toxic_comments.describe()
# Out:
#              score   toxic  severe_toxic      obscene       threat  \
# count  3943.000000  3943.0   3943.000000  3943.000000  3943.000000
# mean      0.833664     1.0      0.096120     0.522698     0.029673
# std       0.168672     0.0      0.294793     0.499548     0.169705
# min       0.054399     1.0      0.000000     0.000000     0.000000
# 25%       0.771053     1.0      0.000000     0.000000     0.000000
# 50%       0.890928     1.0      0.000000     1.000000     0.000000
# 75%       0.954737     1.0      0.000000     1.000000     0.000000
# max       0.998329     1.0      1.000000     1.000000     1.000000
#
#             insult  identity_hate
# count  3943.000000    3943.000000
# mean      0.487700       0.095612
# std       0.499912       0.294096
# min       0.000000       0.000000
# 25%       0.000000       0.000000
# 50%       0.000000       0.000000
# 75%       1.000000       0.000000
# max       1.000000       1.000000

# %% [markdown]
# Threshold of 0.7 chosen due to most (approximately 75%) of the toxic comments having a score above 0.77.

# %%
toxic_comments.head()
# Out:
#                   id                                       comment_text  \
# 8   00091c35fa9d0465  == Arabs are committing genocide in Iraq, but ...
# 24  0013fed3aeae76b7  DJ Robinson is gay as hell! he sucks his dick ...
# 29  0017d4d47894af05               :Fuck off, you anti-semitic cunt.  |
# 37  001d739c97bc2ae4  How dare you vandalize that page about the HMS...
# 38  001eff4007dbb65b  ::No, he is an arrogant, self serving, immatur...
#
#        score  toxic  severe_toxic  obscene  threat  insult  identity_hate
# 8   0.635929      1             0        0       0       0              0
# 24  0.989706      1             0        1       0       1              1
# 29  0.959459      1             0        1       0       1              0
# 37  0.564152      1             0        0       0       0              0
# 38  0.956893      1             0        1       0       1              0

# %% [markdown]
# From looking at the first few rows, I could immediately see that two comments with the highest rated scores contain words that
# are sexual or sexuality related (lines 24 & 29).

# %% [markdown]
# Checking the scores of these words using the API. Since they're not relatively low, I think they're important to consider in my analysis.

# %%
comment_list = ['gay', 'dick', 'cunt']
score_list = []

for comment in comment_list:
    score = get_toxicity_score(comment)
    time.sleep(1)
    score_list.append(score)

print(score_list)
# Out:
# [0.61826205, 0.59863794, 0.5026305]

# %%
sum (score_list)
# Out:
# 1.71953049

# %% [markdown]
# This allows me to form my hypothesis, stated below:

# %% [markdown]
# ## ***Hypothesis: Comments containing sexual or sexuality-related terms are more likely to be scored as "toxic" by the Perspective model. Perspective is more biased when scoring comments containing sexual or sexuality-related terms.***

# %% [markdown]
# Extracting all comments from the original dataset with sexual/sexuality-related terms.

# %%
contain_certain_words = df.loc[df.comment_text.str.contains(r'\b(?:gay|queer|homo|binary|lesbian|homosexual|homophobic|asexual|cunt|pansexual|hetero|heterosexual|transsexual|dick|anus|LGBTQ|vag|vagina|demisexual|polysexual|penis|ass|butt|cock|sack|transgender|sex|sexual|sexuality|sexually|sexual orientation|pangender|homophobia|intergender|gender-fluid|femme|cisgender|biphobia|bigender|abrosexual|agender|arrse|arse|orgasm|fag|faggot|balls|bellend|dickhead|knobend|slut|whore|tits|boobs|boobies)\b')]

# %% [markdown]
# Terms were chosen by looking at the first few rows of the toxic comments (shown below), and by looking at websites such as https://www.portlandoregon.gov/article/730061 and https://www.fluentin3months.com/dirty-words/. Only English terms were considered.

# %%
toxic_comments.head(60)
# Out:
#                    id                                       comment_text  \
# 8    00091c35fa9d0465  == Arabs are committing genocide in Iraq, but ...
# 24   0013fed3aeae76b7  DJ Robinson is gay as hell! he sucks his dick ...
# 29   0017d4d47894af05               :Fuck off, you anti-semitic cunt.  |
# 37   001d739c97bc2ae4  How dare you vandalize that page about the HMS...
# 38   001eff4007dbb65b  ::No, he is an arrogant, self serving, immatur...
# 59   03c1c7a2649a7d87  :::Jeez Ed, you seem like a fucking shitty dou...
# 61   03c45b72d38c1f75  FUCK OFF FUCK OFF FUCK OFF FUCK OFF FUCK OFF F...
# 62   03c6344729c4e665  Azerbaijanis Proud of Ramil Safarov  \n If I h...
# 71   03d4fd1aab9247a2  who is DJMASACRE? \n\n what the heck is a sock...
# 80   03df07faf434d387  " \n :Yeah your right. And dude I'm not fuckin...
# 123  07e0fe7770ca2abe  Bill \n\n  \n\n  \n\n  \n dear \n sir \n\n  \n...
# 129  07e974f96b296e08  Good Bye Intoronto1125. RIP !!!! Hope to see y...
# 143  0bc799a58279849f                         I knew he was a dirty jew.
# 158  0bdd3e5962caf581  ::Arguing with a conpiracy theorist is like tr...
# 179  0f78176e81fc8269  ' \n\n  \n WHAT IS WRONG WITH YOU YOU STUPID G...
# 210  0f98c8a6a7fa84d3  vandels are makin your vag extra wide. please ...
# 211  0f99eac748f1ba88  I sincerely appologise for the stupidity of my...
# 240  137df37e25c41d7a  " (UTC) \n\n Stupid! ""ß"" is a ligature of sz...
# 286  16ce3799c29e3bdb  :This is stupid. How does it even get started?...
# 291  16d2c7fba677c4ce                           rather than a stupid one
# 300  16dc9ea6673acf07  In my opinion, the only reason they've chosen ...
# 304  16e010a6cdefef2c  " \n You're a fucking idiot. Just because it t...
# 313  16f0b43ffab85e36  == The Bealtes>ABBA == \n\n abba sucks, the pe...
# 315  1a17976be8da3231  " 2007 (UTC) \n\n :Dude, saying stuff like  \n...
# 318  1a299d1305ed346c  " \n\n Very biased post. Aside from Itlaians a...
# 330  1a3ffaa9e319104c  ==Yo mama== \n This is yo mama and I know that...
# 332  1a44cad92a0c1c96  ==Son of a bitch== \n\n Hey you fucking neo-Na...
# 333  1a45b872642fde4a                                         human anus
# 338  1a4c6302cea3ffe2  Dick Cheney will fucking kill all of those god...
# 348  1a5b9d18709ce80a  Ur a dick im sure u have nothing better to do ...
# 360  1deaacb5181ae452                         ::Mooch ass grassy ass. ..
# 364  1decea56597a550e  Oh, go on! Write a blog \n Why is that Pakista...
# 367  1def945297b88f92             == You idiot == \n\n I'm only kidding!
# 387  1e14ca263c1fca71  '''WANK WANK WANK WANK  \n\n  \n WANK WANK WAN...
# 388  1e152e3d52ad0f60  " \n *OK, I should have called this ""You cunt...
# 394  1e2019c0cb3692a1                Bro, you messin brav? I'll bang you
# 402  20a8848a69c24360                         i love to suck donkey cock
# 403  20ae76773aa0917e    that penis was........it made me super horny!!!
# 405  20b3c3f5bc7c08c9  ::You idiotic wikipedians! I am a student in e...
# 408  20b6b15234429f4f                          RILEY HAS THE BEST VAGINA
# 413  20bd6871b72e8721  Are you kidding me?! It's HIS blog!  How do I ...
# 417  20c393e2a52dbfce  YAY FAGGOTS FAAAAGGGGOOOTSSS ARE AWESOME YAY Y...
# 429  20cc67e22fdc3738       == Move to liverpool == \n\n This is rubbish
# 430  20cdeb8ee999a478  == You know what smart arrse........phuck a bi...
# 447  2412ef2ce6f87a73  SSJ, the only way that fucking pitiful excuse ...
# 448  2415514803eb80a4  I can post whatever the fuck I want. This is t...
# 457  241f974542ed5c92                                       I am a penis
# 461  24246b3d3097edee  ::The Germans are pathetic so I'm not even goi...
# 467  2429f1a163a62c8c  ++++++++++++++++++ \n\n How dare I add a link ...
# 473  242eeac249746a9d            hes innocent you DUMB BITCH INVESTIGATE
# 475  24334625e636ddd1  faty faty faty faty cow balls are fucking your...
# 476  2433d7112e3da3c6  " \n\n  \n\n :::I have heard people describe M...
# 499  27fd602f4efae825  " \n :Haha... Kick ass, take names. What's you...
# 508  280c710ec006823b  ==Thanks== \n Thanks to Biruitorul and Ronline...
# 511  2811d5bbb5daa20a  " \n **I feel exactly this way too, even thoug...
# 528  28325b8f64bafe2f                            u are a gigantic faggot
# 556  2bebc4b7de2648e3  THIS IS WHAT YOUR FAT PIG OF A LEADER DEALS IN...
# 559  2beeb9e39f72c459  What the hell did I make a Bibliography for if...
# 565  2bf617588eaed5c6  "::Probably some Yiddish or dialectal variant ...
# 568  2bf81624b06ce086                          :You're fuckin' right. -)
#
#         score  toxic  severe_toxic  obscene  threat  insult  identity_hate
# 8    0.635929      1             0        0       0       0              0
# 24   0.989706      1             0        1       0       1              1
# 29   0.959459      1             0        1       0       1              0
# 37   0.564152      1             0        0       0       0              0
# 38   0.956893      1             0        1       0       1              0
# 59   0.992469      1             0        1       0       1              0
# 61   0.989706      1             0        1       0       0              0
# 62   0.980994      1             0        1       1       1              1
# 71   0.851035      1             0        0       0       0              0
# 80   0.878531      1             0        0       0       0              0
# 123  0.913934      1             0        0       0       1              1
# 129  0.585356      1             0        0       0       0              0
# 143  0.909082      1             0        0       0       1              1
# 158  0.796248      1             0        1       0       0              0
# 179  0.961847      1             0        1       0       1              0
# 210  0.959067      1             0        1       0       1              1
# 211  0.848655      1             0        0       0       0              0
# 240  0.843952      1             0        0       0       1              0
# 286  0.835521      1             0        0       0       0              0
# 291  0.887998      1             0        0       0       1              0
# 300  0.796203      1             0        1       0       0              0
# 304  0.977299      1             0        1       0       1              0
# 313  0.695427      1             0        0       0       0              0
# 315  0.918381      1             0        1       0       1              0
# 318  0.768198      1             0        0       0       0              0
# 330  0.959383      1             1        1       0       1              0
# 332  0.992705      1             1        1       0       1              1
# 333  0.888247      1             0        0       0       0              0
# 338  0.951699      1             1        1       1       1              1
# 348  0.949928      1             0        1       0       1              0
# 360  0.940109      1             0        1       0       0              0
# 364  0.888247      1             0        0       0       1              0
# 367  0.962530      1             0        1       0       1              0
# 387  0.915653      1             0        1       0       1              0
# 388  0.835521      1             0        0       0       0              0
# 394  0.749507      1             0        0       1       0              0
# 402  0.959702      1             0        1       0       0              0
# 403  0.940933      1             0        1       0       0              0
# 405  0.910683      1             0        0       0       1              0
# 408  0.878531      1             0        1       0       0              0
# 413  0.897338      1             0        0       0       0              0
# 417  0.932329      1             0        1       0       0              1
# 429  0.648201      1             0        0       0       0              0
# 430  0.928721      1             1        1       0       1              0
# 447  0.977829      1             1        1       1       1              0
# 448  0.932329      1             0        1       0       1              0
# 457  0.854843      1             0        1       0       0              0
# 461  0.709312      1             0        0       0       0              1
# 467  0.932523      1             0        1       0       1              0
# 473  0.958925      1             0        1       0       1              0
# 475  0.989706      1             0        1       0       1              0
# 476  0.948086      1             0        1       0       1              0
# 499  0.945132      1             0        1       0       0              0
# 508  0.702246      1             0        0       0       0              0
# 511  0.775678      1             0        1       0       0              0
# 528  0.965499      1             0        1       0       1              1
# 556  0.915653      1             0        0       0       0              0
# 559  0.878531      1             0        1       0       1              0
# 565  0.878531      1             0        1       0       0              0
# 568  0.903342      1             0        1       0       0              0

# %%
contain_certain_words.describe()
# Out:
#              score        toxic  severe_toxic      obscene       threat  \
# count  1306.000000  1306.000000   1306.000000  1306.000000  1306.000000
# mean      0.770280     0.643185      0.107198     0.496937     0.028331
# std       0.245123     0.479243      0.309483     0.500182     0.165980
# min       0.019900     0.000000      0.000000     0.000000     0.000000
# 25%       0.627064     0.000000      0.000000     0.000000     0.000000
# 50%       0.881638     1.000000      0.000000     0.000000     0.000000
# 75%       0.959269     1.000000      0.000000     1.000000     0.000000
# max       0.996048     1.000000      1.000000     1.000000     1.000000
#
#             insult  identity_hate
# count  1306.000000    1306.000000
# mean      0.421899       0.131700
# std       0.494052       0.338294
# min       0.000000       0.000000
# 25%       0.000000       0.000000
# 50%       0.000000       0.000000
# 75%       1.000000       0.000000
# max       1.000000       1.000000

# %% [markdown]
# Determine how many of these comments are considered toxic by the model, according to our threshold. From these results, we could see that **918** comments are toxic.

# %%
threshold = 0.7

prediction = contain_certain_words['score'] > threshold
prediction.value_counts()
# Out:
# True     918
# False    388
# Name: score, dtype: int64

# %% [markdown]
# From the comments that contain these certain terms, extract the ones that were actually labeled as "toxic" by manual reviewers.

# %%
toxic_by_humans = contain_certain_words[(contain_certain_words['toxic']==1)]

# %% [markdown]
# From the output below, we could see that **840** comments are toxic according to human input.

# %%
toxic_by_humans.describe()
# Out:
#             score  toxic  severe_toxic     obscene      threat      insult  \
# count  840.000000  840.0    840.000000  840.000000  840.000000  840.000000
# mean     0.908398    1.0      0.166667    0.734524    0.044048    0.629762
# std      0.105231    0.0      0.372900    0.441850    0.205323    0.483156
# min      0.082855    1.0      0.000000    0.000000    0.000000    0.000000
# 25%      0.880260    1.0      0.000000    0.000000    0.000000    0.000000
# 50%      0.948086    1.0      0.000000    1.000000    0.000000    1.000000
# 75%      0.974570    1.0      0.000000    1.000000    0.000000    1.000000
# max      0.996048    1.0      1.000000    1.000000    1.000000    1.000000
#
#        identity_hate
# count     840.000000
# mean        0.198810
# std         0.399342
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %% [markdown]
# Based on this, we could say that the model over-estimated the number of toxic comments that contained sexual/sexuality-related
# terms. The difference between the number of toxic comments rated by the model and manual reviewers is 78 (918 and 840, respectfully.) These results **support** my initial **hypothesis** that **the Perspective model is slightly biased towards comments containing sexual/sexuality-related terms**.

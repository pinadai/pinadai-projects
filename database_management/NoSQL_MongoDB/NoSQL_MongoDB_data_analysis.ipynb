# %% [markdown]
# # NoSQL: MongoDB data analysis

# %%
# %env HOST=XXXXX
# %env USER=XXXXX
# %env PW=CXXXXX

# %%
CONNECT="/usr/bin/mongosh $HOST -u $USER -p $PW --quiet"

# %%
# !{CONNECT}

# %%
# !{CONNECT} --eval "show collections"

# %%
# !{CONNECT} --eval "db.data.findOne()"

# %% [markdown]
# ## Begin Work

# %%
# !{CONNECT} -f /home/jupyter/proj6/project6_queries.js
# Out:
#  ****************************************************************
# 1) Returns pressures that are not too low or too high, between a range of 1008 and 1050. Sorts the results in ascending order. Limits the query results to 3.
# {
#   'pressure.value': {
#     '$gt': 1008,
#     '$lt': 1050
#   }
# }
# {
#   pressure: 1,
#   ts: 1,
#   _id: 0
# }
# [
#   {
#     ts: ISODate("1984-03-08T00:00:00.000Z"),
#     pressure: {
#       value: 1008.1,
#       quality: '1'
#     }
#   },
#   {
#     ts: ISODate("1984-03-08T00:00:00.000Z"),
#     pressure: {
#       value: 1008.1,
#       quality: '1'
#     }
#   },
#   {
#     ts: ISODate("1984-03-05T18:00:00.000Z"),
#     pressure: {
#       value: 1008.1,
#       quality: '1'
#     }
#   }
# ]
# ****************************************************************
# 2) Returns those whose callLetters are either VC81 or TFBY.
# {
#   '$or': [
#     {
#       callLetters: 'VC81'
#     },
#     {
#       callLetters: 'TFBY'
#     }
#   ]
# }
# {
# ...

# %% [markdown]
# ## Begin Extra Credit Work

# %%
# !{CONNECT} -f /home/jupyter/proj6/exam1_extra_credit.js
# Out:
#  ****************************************************************
# 1) Inserts a new document into the sample_weatherdata data collection using insertOne().
# {
#   st: 'x+12345-654321',
#   elevation: 9999,
#   callLetters: 'DRRP',
#   dataSource: '4',
#   type: 'DP-07'
# }
# {
#   acknowledged: true,
#   insertedId: ObjectId("653be76d0543356cf45e3247")
# }
# ****************************************************************
# 2) Inserts 3 documents that have the call letters 'LAQU' and have 'VO20' as the quality control process using insertMany().
# [
#   {
#     st: 'x+54601-019308',
#     elevation: 9999,
#     callLetters: 'LAQU',
#     qualityControlProcess: 'VO20',
#     dataSource: '4'
#   },
#   {
#     st: 'x+37856-097561',
#     elevation: 9999,
#     callLetters: 'LAQU',
#     qualityControlProcess: 'VO20',
#     dataSource: '4'
#   },
#   {
#     st: 'x+67439-032187',
#     elevation: 9999,
#     callLetters: 'LAQU',
#     qualityControlProcess: 'VO20',
# ...
